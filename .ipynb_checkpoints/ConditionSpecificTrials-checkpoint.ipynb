# %% [markdown]
# # Extracting condition-specific trials
#
# The aim of this section is to extract the trials according to the condition labels derived from the trigger channels. Once the trials are extracted, bad epochs will be identified and excluded based on their peak-to-peak signal amplitude.

# %% [markdown]
# ## Preparation
# ### Import the necessary modules
# Below are the required Python modules to be imported

# %%
import os.path as op
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import mne
from mne_bids import BIDSPath, read_raw_bids

# %% [markdown]
# ### File overview
#
# The chapter relies on the input file (embedded in the BIDS structure):
#
# < BIDS_ROOT >/derivatives/Preprocessing/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-01_ica_raw.fif
#
#
# < BIDS_ROOT >/derivatives/Preprocessing/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-01_ann.fif
#
#
# and generates the output files
#
# < BIDS_ROOT >/derivatives/Analysis/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-12_epo.fif
#
# Set the paths for the data and results. Note that these will depend on your local setup.

# %%
subject = '01'
session = '01'
task = 'SpAtt'
run = '01'
meg_suffix = 'meg'
ica_suffix = 'ica_raw'
epo_suffix = 'epo'

data_path='E:/Sub_01/Data'


bids_root = op.join(data_path, "Cerca_Spatt_BIDS")
deriv_root1 = op.join(bids_root, "derivatives/preprocessing")
deriv_root2=op.join(bids_root, "derivatives/analysis")

bids_path_preproc = BIDSPath(subject=subject, session=session,
            task=task, run=run, suffix=ica_suffix, datatype='meg',
            root=deriv_root1, extension='.fif', check=False)


bids_path = BIDSPath(subject=subject, session=session,
            task=task, run=run, suffix=epo_suffix, datatype='meg',
            root=deriv_root2, extension='.fif', check=False).mkdir()
  
deriv_fname = bids_path

print(bids_path_preproc.fpath)
print(deriv_fname)
# Out:
# E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\ses-01\meg\sub-01_ses-01_task-SpAtt_run-01_ica_raw.fif
# E:/Sub_01/Data/Cerca_Spatt_BIDS/derivatives/analysis/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-01_epo.fif

# %% [markdown]
# ## Reading the events from the stimulus channels
#
# First, read all the raw data fron the previous section in which artefacts were attenuated by ICA:

# %%
raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False},verbose=True)
# Out:
# Opening raw data file E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\ses-01\meg\sub-01_ses-01_task-SpAtt_run-01_ica_raw.fif...
#     Read a total of 3 projection items:
#         HFC: l=1 m=0 (1 x 180) active
#         HFC: l=1 m=-1 (1 x 180) active
#         HFC: l=1 m=1 (1 x 180) active
#     Range : 0 ... 1241951 =      0.000 ...  1655.935 secs
# Ready.
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\1308987296.py:1: RuntimeWarning: Did not find any events.tsv associated with sub-01_ses-01_task-SpAtt_run-01.
#
# The search_str was "E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\**\meg\sub-01_ses-01*events.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False},verbose=True)
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\1308987296.py:1: RuntimeWarning: Did not find any channels.tsv associated with sub-01_ses-01_task-SpAtt_run-01.
#
# The search_str was "E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\**\meg\sub-01_ses-01*channels.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False},verbose=True)
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\1308987296.py:1: RuntimeWarning: Did not find any meg.json associated with sub-01_ses-01_task-SpAtt_run-01.
#
# The search_str was "E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\**\meg\sub-01_ses-01*meg.json"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False},verbose=True)
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\1308987296.py:1: RuntimeWarning: participants.tsv file not found for E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\ses-01\meg\sub-01_ses-01_task-SpAtt_run-01_ica_raw.fif
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False},verbose=True)

# %% [markdown]
# The following code will read the events according to annotations assigned with the BIDS formatting was done:

# %%
events, events_id = mne.events_from_annotations(raw,event_id='auto')
# Out:
# Used Annotations descriptions: [np.str_('StimOnset'), np.str_('cue_Left'), np.str_('cue_Right'), np.str_('dotOnLeft'), np.str_('dotOnRight'), np.str_('resp_L'), np.str_('resp_T')]

# %% [markdown]
# The annotations are represented in the array *events* where the first column is the sample and the third column the corresponding trigger value. The *events_id* is a dictionary of event names and trigger codes.
#
# To visualise the *event_id*s and a snippet of the *events*-array write:

# %%
events_id
# Out:
# {np.str_('StimOnset'): 1,
#  np.str_('cue_Left'): 2,
#  np.str_('cue_Right'): 3,
#  np.str_('dotOnLeft'): 4,
#  np.str_('dotOnRight'): 5,
#  np.str_('resp_L'): 6,
#  np.str_('resp_T'): 7}

# %%
events[100:120]
# Out:
# array([[ 98021,      0,      2],
#        [ 98965,      0,      1],
#        [100141,      0,      4],
#        [100724,      0,      7],
#        [101422,      0,      3],
#        [102366,      0,      1],
#        [103222,      0,      5],
#        [103805,      0,      7],
#        [104766,      0,      2],
#        [105710,      0,      1],
#        [106348,      0,      4],
#        [106852,      0,      7],
#        [107904,      0,      2],
#        [108848,      0,      1],
#        [109373,      0,      4],
#        [109889,      0,      7],
#        [110798,      0,      3],
#        [111742,      0,      1],
#        [112249,      0,      5],
#        [112715,      0,      7]])

# %% [markdown]
# To visualise the marked events along with the time course of the raw data in a browsing window, write:

# %%
# %matplotlib inline
raw.plot(start=500)

# %% [markdown]
# ## Defining the epochs (trials) according to the event values
#
# The next step is to extract the left and right trials of the data defined according to respectively *cue_Left* and *cue_Right*

# %%
bids_path_preproc.update(run='01')
raw = read_raw_bids(bids_path=bids_path_preproc, 
                    extra_params={'preload': True}, 
                    verbose=True)
events, events_id = mne.events_from_annotations(raw, event_id='auto')

raw_list = [raw]
events_list = [events]

events_picks_id = {k: v for k, v in events_id.items() if k.startswith('cue')};
# Out:
# Opening raw data file E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\ses-01\meg\sub-01_ses-01_task-SpAtt_run-01_ica_raw.fif...
#     Read a total of 3 projection items:
#         HFC: l=1 m=0 (1 x 180) active
#         HFC: l=1 m=-1 (1 x 180) active
#         HFC: l=1 m=1 (1 x 180) active
#     Range : 0 ... 1241951 =      0.000 ...  1655.935 secs
# Ready.
# Reading 0 ... 1241951  =      0.000 ...  1655.935 secs...
# Used Annotations descriptions: [np.str_('StimOnset'), np.str_('cue_Left'), np.str_('cue_Right'), np.str_('dotOnLeft'), np.str_('dotOnRight'), np.str_('resp_L'), np.str_('resp_T')]
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\385416671.py:2: RuntimeWarning: Did not find any events.tsv associated with sub-01_ses-01_task-SpAtt_run-01.
#
# The search_str was "E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\**\meg\sub-01_ses-01*events.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc,
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\385416671.py:2: RuntimeWarning: Did not find any channels.tsv associated with sub-01_ses-01_task-SpAtt_run-01.
#
# The search_str was "E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\**\meg\sub-01_ses-01*channels.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc,
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\385416671.py:2: RuntimeWarning: Did not find any meg.json associated with sub-01_ses-01_task-SpAtt_run-01.
#
# The search_str was "E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\**\meg\sub-01_ses-01*meg.json"
#   raw = read_raw_bids(bids_path=bids_path_preproc,
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\385416671.py:2: RuntimeWarning: participants.tsv file not found for E:\Sub_01\Data\Cerca_Spatt_BIDS\derivatives\preprocessing\sub-01\ses-01\meg\sub-01_ses-01_task-SpAtt_run-01_ica_raw.fif
#   raw = read_raw_bids(bids_path=bids_path_preproc,

# %% [markdown]
# As a check, print the picked ids:

# %%
print(events_picks_id)
# Out:
# {np.str_('cue_Left'): 2, np.str_('cue_Right'): 3}

# %% [markdown]
# Set the peak-to-peak amplitude thresholds for trial rejection. This is an extra setting for ensuring that trials with excessive artefacts are rejected. Eventually, this should be implemented as an annotation in the Artefect Rejection chapter.
# These values may change depending on the quality of the data.

# %%
reject = dict(mag=2.5e-11)

# %% [markdown]
# Time windows of interest are -0.75 to 2 s epochs aligned to the onset of the left and right cues. Now perform the epoching:

# %%
epochs = mne.Epochs(raw,
            events, events_picks_id,
            tmin=-0.75 , tmax=2,
            baseline=None,
            proj=False,
            picks = 'all',
            detrend = 1,
            reject=reject,
            reject_by_annotation=True,
            preload=True,
            verbose=False)

# %% [markdown]
# To display the details of the epochs write

# %%
epochs
# Out:
# C:\Users\arakshit\mne-python\1.10.1_0\Lib\site-packages\IPython\core\formatters.py:406: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   return method()
# <Epochs | 316 events (all good), -0.749 – 2 s (baseline off), ~901.9 MiB, data loaded,
#  np.str_('cue_Left'): 160
#  np.str_('cue_Right'): 156>

# %% [markdown]
# Note that there are 113 cue left trials and 106 cue right trials.
#
# Now plot an overview of the rejected epochs:

# %%
# %matplotlib inline
epochs.plot_drop_log();

# %% [markdown]
# A small percentage of the trials were rejected due to artefacts in the magnetometers.
#
# Now we save the epoched data in an FIF-file.

# %%
print(deriv_fname)
# Out:
# E:/Sub_01/Data/Cerca_Spatt_BIDS/derivatives/analysis/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-01_epo.fif

# %%
epochs.save(deriv_fname, overwrite=True)
# Out:
# [WindowsPath('E:/Sub_01/Data/Cerca_Spatt_BIDS/derivatives/analysis/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-01_epo.fif')]

# %% [markdown]
# ## Plotting the trials
#
# To show the trials for the left cue condition for the OPM sensors:

# %%
OPMZ = [item for item in epochs.ch_names if item.endswith("Z") and not item.startswith("BNC")]
epochs['cue_Left'].plot(picks=OPMZ)
# Out:
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\2836857852.py:2: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   epochs['cue_Left'].plot(picks=OPMZ)
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\2836857852.py:2: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   epochs['cue_Left'].plot(picks=OPMZ)
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\2836857852.py:2: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   epochs['cue_Left'].plot(picks=OPMZ)
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\2836857852.py:2: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   epochs['cue_Left'].plot(picks=OPMZ)
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\2836857852.py:2: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   epochs['cue_Left'].plot(picks=OPMZ)
# Using qt as 2D backend.
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\2836857852.py:2: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   epochs['cue_Left'].plot(picks=OPMZ)

# %% [markdown]
# The plot above shows the trials cued to the left.

# %% [markdown]
# To show all the trials belonging to left for a representative OPM Sensor (O6 H1 Z) use the plot_image function. In the following example we also lowpass filter the indvidual trials at 30 Hz and shorten them (crop) to a -100 to 400 ms interval:

# %%
epochs['cue_Right'].filter(0.1,30).crop(-0.1,0.4).apply_baseline(baseline=(-0.1, 0)).plot_image(picks=['O7 H5 Z'], vmin=-2500, vmax=2500);
# Out:
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 24751 samples (33.001 s)
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\3823878019.py:1: RuntimeWarning: filter_length (24751) is longer than the signal (2063), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs['cue_Right'].filter(0.1,30).crop(-0.1,0.4).apply_baseline(baseline=(-0.1, 0)).plot_image(picks=['O3 G5 Z'], vmin=-2500, vmax=2500);
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\3823878019.py:1: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   epochs['cue_Right'].filter(0.1,30).crop(-0.1,0.4).apply_baseline(baseline=(-0.1, 0)).plot_image(picks=['O3 G5 Z'], vmin=-2500, vmax=2500);
# C:\Users\arakshit\AppData\Local\Temp\ipykernel_29632\3823878019.py:1: RuntimeWarning: The MNE-Python config file (C:\Users\arakshit\.mne\mne-python.json) is not a valid JSON file and might be corrupted
#   epochs['cue_Right'].filter(0.1,30).crop(-0.1,0.4).apply_baseline(baseline=(-0.1, 0)).plot_image(picks=['O3 G5 Z'], vmin=-2500, vmax=2500);
# Applying baseline correction (mode: mean)
# Not setting metadata
# 156 matching events found
# No baseline correction applied
# 0 projection items activated

# %% [markdown]
# ## Preregistration and Publications

# %% [markdown]
# "Trials were extracted from the continuous data from –0.75 to 2 seconds around each cue onset. A linear detrend removal was used to reduce slow drifts. Trials with eye-blinks, muscle artefacts as well as large field values were excluded. In total, 39% of the trials were removed."
